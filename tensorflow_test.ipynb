# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./gas_news.csv", parse_dates=['DATE'], sep=';')

# %%
df
# Out:
#            DATE TOPIC                                              TITLE  \
# 0    2022-12-21   gas       A Crisis Is Looming For The U.S. Energy Grid
# 1    2022-12-21   gas  Controversial Gas Cap Could Lead To Less LNG F...
# 2    2022-12-20   gas  Deadly Blast Destroys Russia-Ukraine Gas Expor...
# 3    2022-12-20   gas  Will Iraq Finally Start To Use Its Natural Gas...
# 4    2022-12-12   gas  Saudi Arabia Uses Contested Gas Field As A Geo...
# ...         ...   ...                                                ...
# 1595 2011-10-31   gas  Natural Gas Analysis for the Week of October 3...
# 1596 2011-10-28   gas  Apocalypse Redux? U.S. Natural Gas Find off Vi...
# 1597 2011-10-27   gas  Jordan Scrambling to Replace Lost Egyptian Nat...
# 1598 2011-10-24   gas  Natural Gas Analysis for the Week of October 2...
# 1599 2011-10-19   gas  Azerbaijan: Baku's Natural Gas Discoveries Rev...
#
#                                                    LINK  \
# ...

# %%
processed_df = pd.DataFrame()
processed_df['DATE'] = df.DATE
processed_df['ORIGINAL_LENGHT'] = [len(x.split()) for x in df.CONTENT]
processed_df['CONTENT'] = [f"[CLS] {x.lower().split()[:200] + x.lower().split()[-200:]} [SEP]" for x in df.CONTENT]

# %%
import torch

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cpu')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[28], line 3
#       1 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#       2 n_gpu = torch.cuda.device_count()
# ----> 3 torch.cuda.get_device_name(0)
#
# File c:\Users\domca\anaconda3\envs\tf\lib\site-packages\torch\cuda\__init__.py:341, in get_device_name(device)
#     329 def get_device_name(device: Optional[_device_t] = None) -> str:
#     330     r"""Gets the name of a device.
#     331
#     332     Args:
#    (...)
#     339         str: the name of the device
#     340     """
# --> 341     return get_device_properties(device).name
#
# File c:\Users\domca\anaconda3\envs\tf\lib\site-packages\torch\cuda\__init__.py:371, in get_device_properties(device)
#     361 def get_device_properties(device: _device_t) -> _CudaDeviceProperties:
#     362     r"""Gets the properties of a device.
#     363
# ...
