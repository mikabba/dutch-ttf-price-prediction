# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./gas_news.csv", parse_dates=['DATE'], sep=';')

# %%
""" lines = []
with open("./gas_prices.csv", "r") as file:
    for line in file:
        lines.append(line.replace("\"", ""))

with open("./gas_prices_new.csv", "w") as file:
    for line in lines:
        file.write(line) """
# Out:
# ' lines = []\nwith open("./gas_prices.csv", "r") as file:\n    for line in file:\n        lines.append(line.replace(""", ""))\n\nwith open("./gas_prices_new.csv", "w") as file:\n    for line in lines:\n        file.write(line) '

# %%
df_prices = pd.read_csv("./gas_prices_new.csv", sep=',', parse_dates=['Date'])

# %%
df_prices.plot(x='Date', y='Price')
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
from prophet import Prophet

# %%
ts = df_prices[['Date', 'Price']].rename(columns={'Date': 'ds', 'Price':'y'})

# %%
m = Prophet()
m.add_seasonality(name='monthly', period=30.5, fourier_order=5)
m.fit(ts)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# c:\Users\domca\anaconda3\envs\AIML_Project\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
future = m.make_future_dataframe(periods=60)
forecast = m.predict(future)
# Out:
# c:\Users\domca\anaconda3\envs\AIML_Project\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# c:\Users\domca\anaconda3\envs\AIML_Project\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
m.plot_components(forecast);
# Out:
# c:\Users\domca\anaconda3\envs\AIML_Project\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# c:\Users\domca\anaconda3\envs\AIML_Project\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# c:\Users\domca\anaconda3\envs\AIML_Project\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
